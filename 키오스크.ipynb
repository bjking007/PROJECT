# %%
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print(self.rect())

        elif self.square == 2:
            print(self.par())
        
        elif self.square == 3:
            print(self.trape())
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        base, height = map(int, input('밑변과 높이를 입력하세요. 예시 : 밑변,높이\n >>> ').split(','))
        area = base * height
        result = '평행사변형의 넓이는 : ' + str(area)
        return result

    def trape(self):
        top, bottom, height = map(int, input('윗변, 아랫변, 높이를 입력하세요. 예시 : 윗변,아랫변,높이\n >>> ').split(','))
        area = (top + bottom) * height / 2
        result = '사다리꼴의 넓이는 : ' + str(area)
        return result

a = Square() 

# 객체 생성 & 2, 3을 각각 입력해 봅시다.
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>>2
# 밑변과 높이를 입력하세요. 예시 : 밑변,높이
#  >>> 3,2
# 평행사변형의 넓이는 : 6

# %%
#잘못작성한 코드

class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        base, height = map(int, input('밑변과 높이를 입력하세요. 예시 : 밑변,높이\n >>> ').split(','))
        area = base * height
        result = '평행사변형의 넓이는 : ' + str(area)
        return result

    def trape(self):
        top, bottom, height = map(int, input('윗변, 아랫변, 높이를 입력하세요. 예시 : 윗변,아랫변,높이\n >>> ').split(','))
        area = (top + bottom) * height / 2
        result = '사다리꼴의 넓이는 : ' + str(area)
        return result

a = Square()
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>>2
# 평행사변형 함수는 par()입니다.

# %%
def menu_select(self):
    self.order_menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']  # 주문 리스트
    self.order_price = [2000, 3000, 3000, 2500, 2500, 3000]  # 가격 리스트
    self.order_menu = []     # 주문한 음료들 저장
    self.order_price = []    # 주문한 가격 저장
    self.price_sum = 0       # 총 가격

def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ':', self.price[i], '원')

def menu_select(self):
    n = 0
    while n < 1 or len(self.menu) < n:
        n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력

        # 메뉴판에 있는 음료 번호일 때
        if 1 <= n & n <= len(self.menu):
            self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
            self.price_sum = self.price[n-1]  # 합계 금액
        
            # 메뉴판에 없는 번호일 때
        else:  
            print("없는 메뉴입니다. 다시 주문해 주세요.")


    # 음료 온도 물어보기
    t = 0  # 기본값을 넣어주고
    while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
        t= int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
        # 문제 2-3의 답을 입력하세요. 
        if t == 1:
                self.temp = "HOT"
        elif t == 2:
                self.temp = "ICE"

        else:    
            print("1과 2 중 하나를 입력하세요.\n")

    self.order_menu.append(self.temp + ' ' + self.menu[n-1])  # 주문 리스트에 추가합니다.
    self.order_price.append(self.price[n-1])# 문제 2-2의 답을 입력하세요. 
    print(self.temp, self.menu[n-1], ' : ', self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.

    # 추가 주문 또는 지불
    while n != 0:  # 지불을 선택하기 전까지 반복합니다.
        print()  # 줄 바꾸면서 
        n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
        if n > 0 and n < len(self.menu) + 1: 
            t = 0
            while t != 1 and t != 2:
                t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                if t == 1:
                    temp = "HOT"
                elif t == 2:
                    temp = "ICE"
                else:
                    print("1과 2 중 하나를 입력하세요.\n")
            # 추가 음료 온도 
            # 문제 2-4. 추가 음료의 온도를 입력받고, 가격 리스트, 주문 리스트, 합계 금액을 업데이트해보세요.
            drink_name = temp + ' ' + self.menu[n-1]
            drink_price = self.price[n-1]
            
            self.order_menu.append(drink_name)
            self.order_price.append(drink_price)
            self.price_sum += drink_price

            print('추가 주문 음료', drink_name, ':', drink_price, '원\n', '합계 : ',self.price_sum, '원')
        else :
            if n == 0 :  # 지불을 입력하면
                print("주문이 완료되었습니다.")
                print("주문 목록 :", self.order_menu)
                print("가격 목록 :", self.order_price)
                print("총 합계 :",self.price_sum)  # 확인을 위한 리스트를 출력합니다.
            else :  # 없는 번호를 입력할 때
                print("없는 메뉴입니다. 다시 주문해 주세요.")
                
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay() #지불
a.table() #주문표 출력

# %%
class Kiosk:    
    def __init__(self):
        self.menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
        self.price = [2000, 3000, 3000, 2500, 2500, 3000]
        self.order_menu = []     # 주문한 음료들 저장
        self.order_price = []    # 주문한 가격 저장
        self.price_sum = 0       # 총 가격

    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ':', self.price[i], '원')

    def menu_select(self):
        n = 0
        while n < 1 or n > len(self.menu):
            n = int(input("음료 번호를 입력하세요 : "))  # 음료 번호 입력

            if 1 <= n <= len(self.menu):
                self.price_sum += self.price[n-1]
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")

        # 온도 입력
        t = 0
        while t != 1 and t != 2:
            t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            if t == 1:
                self.temp = "HOT"
            elif t == 2:
                self.temp = "ICE"
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        drink_name = self.temp + ' ' + self.menu[n-1]
        drink_price = self.price[n-1]

        self.order_menu.append(drink_name)
        self.order_price.append(drink_price)

        print(self.temp, self.menu[n-1], ' : ', drink_price, '원')

        # 추가 주문 루프
        while True:
            print()
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))
            if n == 0:
                print("주문이 완료되었습니다.")
                print("주문 목록 :", self.order_menu)
                print("가격 목록 :", self.order_price)
                print("총 합계 :", self.price_sum, '원')
                break
            elif 1 <= n <= len(self.menu):
                t = 0
                while t != 1 and t != 2:
                    t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
                    if t == 1:
                        temp = "HOT"
                    elif t == 2:
                        temp = "ICE"
                    else:
                        print("1과 2 중 하나를 입력하세요.\n")

                drink_name = temp + ' ' + self.menu[n-1]
                drink_price = self.price[n-1]

                self.order_menu.append(drink_name)
                self.order_price.append(drink_price)
                self.price_sum += drink_price

                print('추가 주문 음료', drink_name, ':', drink_price, '원\n합계 :', self.price_sum, '원')
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")
    def pay(self):
        
        print(f"지불할 금액은 {self.price_sum}원입니다.")
        method = input("지불 수단을 선택하세요 (1: 현금, 2: 카드): ").strip().lower()

        if method in ['1', 'cash']:
            print("직원을 호출하겠습니다.")
        elif method in ['2', 'card']:
            print("IC칩 방향에 맞게 카드를 꽂아주세요.")
        else:
            print("다시 결제를 시도해 주세요.")  
            
            menu_temp = ['HOT americano', 'ICE latte', 'ICE mocha', 'ICE choco_latte'] 
            price_temp = [2000, 3000, 3000, 3000] 

# 외곽
            print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')

# 주문 상품명 : 해당 금액
        for i in range(len(menu_temp)):
             print(menu_temp[i], ' : ', price_temp[i])

             print('합계 금액 :', sum(price_temp))

# 외곽
        for i in range(5):
             print('|' + ' ' * 31+ '|')
             print('⟝' + '-' * 30 + '⟞') 
                
                
a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()
a.table()
# Out:
# 1 americano : 2000 원
# 2 latte : 3000 원
# 3 mocha : 3000 원
# 4 yuza_tea : 2500 원
# 5 green_tea : 2500 원
# 6 choco_latte : 3000 원
# 음료 번호를 입력하세요 : 6
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE choco_latte  :  3000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# 주문 목록 : ['ICE choco_latte']
# 가격 목록 : [3000]
# 총 합계 : 3000 원
# 지불할 금액은 3000원입니다.
# 지불 수단을 선택하세요 (1: 현금, 2: 카드): 1
# 직원을 호출하겠습니다.
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_37/1067037963.py in <module>
#     106 a.menu_print()  # 메뉴 출력
#     107 a.menu_select()  # 주문
# --> 108 a.pay()
#     109 a.table()
#
# /tmp/ipykernel_37/1067037963.py in pay(self)
#      92
#      93 # 주문 상품명 : 해당 금액
# ...
